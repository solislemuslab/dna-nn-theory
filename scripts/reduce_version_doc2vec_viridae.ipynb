# %% [markdown]
# <a href="https://colab.research.google.com/github/csy99/dna-nn-theory/blob/master/reduce_version_doc2vec_viridae.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install PyDrive
# Out:
# Requirement already satisfied: PyDrive in /usr/local/lib/python3.6/dist-packages (1.3.1)
# Requirement already satisfied: PyYAML>=3.0 in /usr/local/lib/python3.6/dist-packages (from PyDrive) (3.13)
# Requirement already satisfied: oauth2client>=4.0.0 in /usr/local/lib/python3.6/dist-packages (from PyDrive) (4.1.3)
# Requirement already satisfied: google-api-python-client>=1.2 in /usr/local/lib/python3.6/dist-packages (from PyDrive) (1.7.12)
# Requirement already satisfied: httplib2>=0.9.1 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (0.17.4)
# Requirement already satisfied: six>=1.6.1 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (1.15.0)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (0.4.8)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (0.2.8)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (4.6)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (3.0.1)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (0.0.4)
# Requirement already satisfied: google-auth>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (1.17.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.4.1->google-api-python-client>=1.2->PyDrive) (4.1.1)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.4.1->google-api-python-client>=1.2->PyDrive) (50.3.0)

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from itertools import product
import re
import time
from sklearn.model_selection import train_test_split
from sklearn.manifold import TSNE
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# # Read Data

# %%
# !pip install PyDrive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Requirement already satisfied: PyDrive in /usr/local/lib/python3.6/dist-packages (1.3.1)
# Requirement already satisfied: google-api-python-client>=1.2 in /usr/local/lib/python3.6/dist-packages (from PyDrive) (1.7.12)
# Requirement already satisfied: oauth2client>=4.0.0 in /usr/local/lib/python3.6/dist-packages (from PyDrive) (4.1.3)
# Requirement already satisfied: PyYAML>=3.0 in /usr/local/lib/python3.6/dist-packages (from PyDrive) (3.13)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (0.0.4)
# Requirement already satisfied: six<2dev,>=1.6.1 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (1.15.0)
# Requirement already satisfied: httplib2<1dev,>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (0.17.4)
# Requirement already satisfied: google-auth>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (1.17.2)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (3.0.1)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (0.2.8)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (4.6)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (0.4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.4.1->google-api-python-client>=1.2->PyDrive) (4.1.1)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.4.1->google-api-python-client>=1.2->PyDrive) (50.3.0)
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !pip install dendropy
# import dendropy

# %%
data_path = '/content/gdrive/My Drive/Colab Notebooks/viridae/'
filename = 'viridae-reduced-1.nex'
label_file = 'clean.csv'
records_df = pd.read_csv(data_path + filename, sep="\t", header=None)
records_df.columns = ["id", "seq"]
records_df['id'] = records_df['id'].str.strip()
records_df['seq'] = records_df['seq'].str.strip()
# replace all '-' with N (stands for any nt)
records_df.seq = records_df.seq.str.replace('-', 'N')
print(len(records_df))
records_df.head()
# Out:
# 281
#             id                                                seq
# 0  NC_000947.1  NNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN...
# 1  NC_001366.1  NNNNNNNNNNTTGAAAGGGGGCCCGGGGGNNNNNNNNNNNNNNNAC...
# 2  NC_001430.1  NNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN...
# 3  NC_001445.1  NNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN...
# 4  NC_001472.1  NNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN...

# %%
labels_df = pd.read_csv(data_path + label_file)
labels_df.drop(['seq'], axis=1, inplace=True)
labels_df.head()
# Out:
#             id  label
# 0  NC_036588.1      0
# 1  NC_014412.1      0
# 2  NC_014413.1      0
# 3  NC_025890.1      0
# 4  NC_023162.1      0

# %%
records_df = records_df.merge(labels_df, on='id', how='left')
records_df.head(5)
# Out:
#             id                                                seq  label
# 0  NC_000947.1  NNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN...      1
# 1  NC_001366.1  NNNNNNNNNNTTGAAAGGGGGCCCGGGGGNNNNNNNNNNNNNNNAC...      0
# 2  NC_001430.1  NNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN...      0
# 3  NC_001445.1  NNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN...      1
# 4  NC_001472.1  NNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN...      0

# %%
seq_len = len(records_df.seq[0])
seq_len
# Out:
# 2449

# %%
def n_gram(x, word_size=3):
  arr_x = [c for c in x]
  words = tf.strings.ngrams(arr_x, ngram_width=word_size, separator='').numpy()
  words = list(pd.Series(words).apply(lambda b: b.decode('utf-8')))
  return words

# %%
records_df["ngram"] = records_df.seq.apply(n_gram)
records_df.head()
# Out:
#             id  ...                                              ngram
# 0  NC_000947.1  ...  [NNN, NNN, NNN, NNN, NNN, NNN, NNN, NNN, NNN, ...
# 1  NC_001366.1  ...  [NNN, NNN, NNN, NNN, NNN, NNN, NNN, NNN, NNT, ...
# 2  NC_001430.1  ...  [NNN, NNN, NNN, NNN, NNN, NNN, NNN, NNN, NNN, ...
# 3  NC_001445.1  ...  [NNN, NNN, NNN, NNN, NNN, NNN, NNN, NNN, NNN, ...
# 4  NC_001472.1  ...  [NNN, NNN, NNN, NNN, NNN, NNN, NNN, NNN, NNN, ...
#
# [5 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(records_df, records_df.label, test_size=0.2, random_state=100, stratify=records_df.label)
xtrain.shape, xtest.shape, ytrain.shape, ytest.shape
# Out:
# ((224, 4), (57, 4), (224,), (57,))

# %%
word_size = 3
vocab = [''.join(c) for c in product('ATCGN', repeat=word_size)]
vocab[:12]
# Out:
# ['AAA',
#  'AAT',
#  'AAC',
#  'AAG',
#  'AAN',
#  'ATA',
#  'ATT',
#  'ATC',
#  'ATG',
#  'ATN',
#  'ACA',
#  'ACT']

# %%
from gensim.models import Doc2Vec
from gensim.models.doc2vec import TaggedDocument
xtrain_tagged = xtrain.apply(
    lambda r: TaggedDocument(words=r["ngram"], tags=[r["label"]]), axis=1
)
xtest_tagged = xtest.apply(
    lambda r: TaggedDocument(words=r["ngram"], tags=[r["label"]]), axis=1
)

# %%
xtrain_tagged.values[0]
# Out:
# TaggedDocument(words=['NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'NNN', 'N ...

# %%
import multiprocessing
from tqdm import tqdm
tqdm.pandas(desc="progress-bar")
cores = multiprocessing.cpu_count()
cores
# Out:
# 2

# %%
def getVec(model, tagged_docs, epochs=20):
  sents = tagged_docs.values
  regressors = [model.infer_vector(doc.words, epochs=epochs) for doc in sents]
  return np.array(regressors)

def plotVec(ax, x, y, title="title"):
  scatter = ax.scatter(x[:, 0], x[:, 1], c=y, 
             cmap=matplotlib.colors.ListedColormap(["red", "blue"]))
  ax.set_title(title)
  ax.legend(*scatter.legend_elements(), loc=0, title="Classes")

def doc2vec_training(embed_size_list=[30,50,80,100], figsize=(10,50), verbose=0):
  num_model = len(embed_size_list)
  fig, axes = plt.subplots(num_model, 2, figsize=figsize)
  counter = 0
  model_list = []
  hist_list = []
  es_cb = keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)
  for embed_size in embed_size_list:
    start = time.time()
    print("training doc2vec for embedding size =", embed_size)
    model_dm = Doc2Vec(dm=1, vector_size=embed_size, negative=5, hs=0, \
                      min_count=2, sample=0, workers=cores)
    if verbose == 1:
      model_dm.build_vocab([x for x in tqdm(xtrain_tagged.values)])
    else:
      model_dm.build_vocab(xtrain_tagged.values)

    for epoch in range(80):
      if verbose == 1:
        model_dm.train([x for x in tqdm(xtrain_tagged.values)], \
              total_examples=len(xtrain_tagged.values), epochs=1)
      else:
        model_dm.train(xtrain_tagged.values, \
              total_examples=len(xtrain_tagged.values), epochs=1)
      model_dm.alpha -= 0.002 
      model_dm.min_alpha = model_dm.alpha
    xtrain_vec = getVec(model_dm, xtrain_tagged)
    xtest_vec = getVec(model_dm, xtest_tagged)
    print("the shape for training vector is", xtrain_vec.shape, \
      "the shape for test vector is", xtest_vec.shape)
    xtrain_tsne = TSNE(n_components=2, metric="cosine").fit_transform(xtrain_vec)
    xtest_tsne = TSNE(n_components=2, metric="cosine").fit_transform(xtest_vec)
    plotVec(axes[counter, 0], xtrain_tsne, ytrain, title="TSNE, training, embedding="+str(embed_size))
    plotVec(axes[counter, 1], xtest_tsne, ytest, title="TSNE, test, embedding="+str(embed_size))
    counter += 1

    print("training NN for embedding size =", embed_size)
    model = keras.Sequential([
      keras.layers.Dense(128, activation="relu", input_shape=[embed_size]),
      keras.layers.Dropout(0.2),
      keras.layers.Dense(64, activation="relu"), 
      keras.layers.Dropout(0.2),
      keras.layers.Dense(32, activation="relu"), 
      keras.layers.Dropout(0.2),
      keras.layers.Dense(16, activation="relu"), 
      keras.layers.Dropout(0.2),
      keras.layers.Dense(1, activation="sigmoid")                        
    ])
    model.compile(keras.optimizers.SGD(momentum=0.9), \
          "binary_crossentropy", metrics=["accuracy"])
    hist = model.fit(xtrain_vec, ytrain, \
          epochs=30, callbacks=[es_cb], validation_split=0.2)
    train_loss, train_acc = model.evaluate(xtrain_vec, ytrain)
    test_loss, test_acc = model.evaluate(xtest_vec, ytest)
    print("Evaluation on training set: loss", train_loss, \
          "accuracy", train_acc)
    print("Evaluation on test set: loss", test_loss, \
          "accuracy", test_acc)
    model_list.append(model)
    hist_list.append(hist)
    end = time.time()
    print("running time in ", end - start, "seconds")
    print("\n\n")
  
  return model_list, hist_list

# %%
embed_size_list = [30,50,60,80]
num_model = len(embed_size_list)
model_list, hist_list = doc2vec_training(embed_size_list=embed_size_list, figsize=(10,20))
# Out:
# training doc2vec for embedding size = 30
# the shape for training vector is (224, 30) the shape for test vector is (57, 30)
# training NN for embedding size = 30
# Epoch 1/30
# 6/6 [==============================] - 0s 27ms/step - loss: 0.8119 - accuracy: 0.5307 - val_loss: 0.6667 - val_accuracy: 0.4667
# Epoch 2/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.7198 - accuracy: 0.4972 - val_loss: 0.6306 - val_accuracy: 0.4667
# Epoch 3/30
# 6/6 [==============================] - 0s 7ms/step - loss: 0.6595 - accuracy: 0.5698 - val_loss: 0.6469 - val_accuracy: 0.7778
# Epoch 4/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6451 - accuracy: 0.6034 - val_loss: 0.5977 - val_accuracy: 0.5778
# Epoch 5/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6188 - accuracy: 0.5978 - val_loss: 0.5517 - val_accuracy: 0.7556
# Epoch 6/30
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5804 - accuracy: 0.6983 - val_loss: 0.5318 - val_accuracy: 0.8222
# Epoch 7/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5710 - accuracy: 0.6927 - val_loss: 0.4818 - val_accuracy: 0.7111
# Epoch 8/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5404 - accuracy: 0.6927 - val_loss: 0.4635 - val_accuracy: 0.8222
# Epoch 9/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5422 - accuracy: 0.7654 - val_loss: 0.5011 - val_accuracy: 0.8000
# Epoch 10/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4691 - accuracy: 0.8101 - val_loss: 0.4619 - val_accuracy: 0.7556
# Epoch 11/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4936 - accuracy: 0.7765 - val_loss: 0.4422 - val_accuracy: 0.8000
# Epoch 12/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4204 - accuracy: 0.8436 - val_loss: 0.4110 - val_accuracy: 0.7556
# Epoch 13/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4663 - accuracy: 0.8045 - val_loss: 0.3961 - val_accuracy: 0.7778
# Epoch 14/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4620 - accuracy: 0.7709 - val_loss: 0.3631 - val_accuracy: 0.8000
# Epoch 15/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3982 - accuracy: 0.8101 - val_loss: 0.3373 - val_accuracy: 0.8222
# Epoch 16/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4027 - accuracy: 0.8324 - val_loss: 0.3360 - val_accuracy: 0.8000
# Epoch 17/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3795 - accuracy: 0.8268 - val_loss: 0.3414 - val_accuracy: 0.8444
# Epoch 18/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4252 - accuracy: 0.7989 - val_loss: 0.3312 - val_accuracy: 0.8444
# Epoch 19/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4041 - accuracy: 0.8101 - val_loss: 0.3024 - val_accuracy: 0.8667
# Epoch 20/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3398 - accuracy: 0.8883 - val_loss: 0.2895 - val_accuracy: 0.8667
# Epoch 21/30
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3242 - accuracy: 0.9162 - val_loss: 0.2965 - val_accuracy: 0.8667
# Epoch 22/30
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3556 - accuracy: 0.8827 - val_loss: 0.3131 - val_accuracy: 0.8222
# Epoch 23/30
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3050 - accuracy: 0.8827 - val_loss: 0.3078 - val_accuracy: 0.8667
# Epoch 24/30
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3418 - accuracy: 0.8659 - val_loss: 0.2841 - val_accuracy: 0.8667
# Epoch 25/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2731 - accuracy: 0.8883 - val_loss: 0.2878 - val_accuracy: 0.8667
# Epoch 26/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2729 - accuracy: 0.8994 - val_loss: 0.2702 - val_accuracy: 0.8889
# Epoch 27/30
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2643 - accuracy: 0.9106 - val_loss: 0.2929 - val_accuracy: 0.8667
# Epoch 28/30
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3107 - accuracy: 0.8939 - val_loss: 0.4989 - val_accuracy: 0.8444
# Epoch 29/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3796 - accuracy: 0.8380 - val_loss: 0.3102 - val_accuracy: 0.8667
# Epoch 30/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3317 - accuracy: 0.8715 - val_loss: 0.2701 - val_accuracy: 0.8667
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2277 - accuracy: 0.9152
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3528 - accuracy: 0.8947
# Evaluation on training set: loss 0.22766096889972687 accuracy 0.9151785969734192
# Evaluation on test set: loss 0.3527770936489105 accuracy 0.8947368264198303
# running time in  58.00075340270996 seconds
#
#
#
# training doc2vec for embedding size = 50
# the shape for training vector is (224, 50) the shape for test vector is (57, 50)
# training NN for embedding size = 50
# Epoch 1/30
# 6/6 [==============================] - 0s 27ms/step - loss: 0.8552 - accuracy: 0.5307 - val_loss: 0.6147 - val_accuracy: 0.6444
# Epoch 2/30
# 6/6 [==============================] - 0s 7ms/step - loss: 0.7042 - accuracy: 0.5196 - val_loss: 0.6010 - val_accuracy: 0.6889
# Epoch 3/30
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6854 - accuracy: 0.6034 - val_loss: 0.6030 - val_accuracy: 0.8000
# Epoch 4/30
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6132 - accuracy: 0.6927 - val_loss: 0.5650 - val_accuracy: 0.6444
# Epoch 5/30
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5927 - accuracy: 0.6872 - val_loss: 0.5754 - val_accuracy: 0.6889
# Epoch 6/30
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5901 - accuracy: 0.7095 - val_loss: 0.5102 - val_accuracy: 0.8222
# Epoch 7/30
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5574 - accuracy: 0.7318 - val_loss: 0.4956 - val_accuracy: 0.7556
# Epoch 8/30
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5774 - accuracy: 0.6927 - val_loss: 0.5675 - val_accuracy: 0.7333
# Epoch 9/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5662 - accuracy: 0.6872 - val_loss: 0.5371 - val_accuracy: 0.8222
# Epoch 10/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5296 - accuracy: 0.7821 - val_loss: 0.4929 - val_accuracy: 0.8000
# Epoch 11/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5454 - accuracy: 0.7263 - val_loss: 0.4918 - val_accuracy: 0.8222
# Epoch 12/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6095 - accuracy: 0.6536 - val_loss: 0.5235 - val_accuracy: 0.8889
# Epoch 13/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5698 - accuracy: 0.7207 - val_loss: 0.5583 - val_accuracy: 0.7556
# Epoch 14/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5336 - accuracy: 0.7486 - val_loss: 0.4940 - val_accuracy: 0.8222
# Epoch 15/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5553 - accuracy: 0.7263 - val_loss: 0.4733 - val_accuracy: 0.8222
# Epoch 16/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5146 - accuracy: 0.7765 - val_loss: 0.5134 - val_accuracy: 0.8000
# Epoch 17/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5117 - accuracy: 0.7709 - val_loss: 0.5236 - val_accuracy: 0.7778
# Epoch 18/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4771 - accuracy: 0.7709 - val_loss: 0.4487 - val_accuracy: 0.8000
# Epoch 19/30
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4968 - accuracy: 0.7709 - val_loss: 0.4858 - val_accuracy: 0.7778
# Epoch 20/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4695 - accuracy: 0.8156 - val_loss: 0.4711 - val_accuracy: 0.8000
# Epoch 21/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5055 - accuracy: 0.7877 - val_loss: 0.4601 - val_accuracy: 0.8444
# Epoch 22/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4457 - accuracy: 0.8045 - val_loss: 0.4557 - val_accuracy: 0.8444
# Epoch 23/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4770 - accuracy: 0.7542 - val_loss: 0.5033 - val_accuracy: 0.7778
# Epoch 24/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4974 - accuracy: 0.8045 - val_loss: 0.4203 - val_accuracy: 0.8444
# Epoch 25/30
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4251 - accuracy: 0.8156 - val_loss: 0.4281 - val_accuracy: 0.8444
# Epoch 26/30
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4871 - accuracy: 0.7989 - val_loss: 0.4422 - val_accuracy: 0.8000
# Epoch 27/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4008 - accuracy: 0.8324 - val_loss: 0.3959 - val_accuracy: 0.8000
# Epoch 28/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4067 - accuracy: 0.8045 - val_loss: 0.4507 - val_accuracy: 0.8222
# Epoch 29/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4235 - accuracy: 0.7989 - val_loss: 0.4011 - val_accuracy: 0.8444
# Epoch 30/30
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4027 - accuracy: 0.8492 - val_loss: 0.3854 - val_accuracy: 0.8444
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3693 - accuracy: 0.8705
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3342 - accuracy: 0.8947
# Evaluation on training set: loss 0.3693417012691498 accuracy 0.8705357313156128
# Evaluation on test set: loss 0.3341718912124634 accuracy 0.8947368264198303
# running time in  53.707698345184326 seconds
#
#
#
# training doc2vec for embedding size = 60
# the shape for training vector is (224, 60) the shape for test vector is (57, 60)
# training NN for embedding size = 60
# Epoch 1/30
# 6/6 [==============================] - 0s 29ms/step - loss: 1.2412 - accuracy: 0.5084 - val_loss: 0.6795 - val_accuracy: 0.6000
# Epoch 2/30
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6878 - accuracy: 0.5978 - val_loss: 0.6572 - val_accuracy: 0.4667
# Epoch 3/30
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6809 - accuracy: 0.5140 - val_loss: 0.6326 - val_accuracy: 0.4667
# Epoch 4/30
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6636 - accuracy: 0.5363 - val_loss: 0.6212 - val_accuracy: 0.4889
# Epoch 5/30
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6770 - accuracy: 0.5084 - val_loss: 0.6154 - val_accuracy: 0.5111
# Epoch 6/30
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6485 - accuracy: 0.5810 - val_loss: 0.6096 - val_accuracy: 0.7556
# Epoch 7/30
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6284 - accuracy: 0.6704 - val_loss: 0.5923 - val_accuracy: 0.7111
# Epoch 8/30
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6432 - accuracy: 0.5642 - val_loss: 0.5781 - val_accuracy: 0.8444
# Epoch 9/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6305 - accuracy: 0.6425 - val_loss: 0.5775 - val_accuracy: 0.8000
# Epoch 10/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5943 - accuracy: 0.7430 - val_loss: 0.5646 - val_accuracy: 0.8222
# Epoch 11/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5954 - accuracy: 0.7151 - val_loss: 0.5355 - val_accuracy: 0.7778
# Epoch 12/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5697 - accuracy: 0.7318 - val_loss: 0.5228 - val_accuracy: 0.8222
# Epoch 13/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6044 - accuracy: 0.6760 - val_loss: 0.5286 - val_accuracy: 0.8222
# Epoch 14/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5871 - accuracy: 0.7263 - val_loss: 0.5087 - val_accuracy: 0.8222
# Epoch 15/30
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5747 - accuracy: 0.7654 - val_loss: 0.4899 - val_accuracy: 0.8222
# Epoch 16/30
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5572 - accuracy: 0.7318 - val_loss: 0.5067 - val_accuracy: 0.8000
# Epoch 17/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4905 - accuracy: 0.7989 - val_loss: 0.4526 - val_accuracy: 0.8000
# Epoch 18/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5446 - accuracy: 0.7318 - val_loss: 0.4467 - val_accuracy: 0.8444
# Epoch 19/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5319 - accuracy: 0.7374 - val_loss: 0.4435 - val_accuracy: 0.8667
# Epoch 20/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5201 - accuracy: 0.7709 - val_loss: 0.4356 - val_accuracy: 0.8000
# Epoch 21/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4816 - accuracy: 0.8101 - val_loss: 0.4426 - val_accuracy: 0.8444
# Epoch 22/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4969 - accuracy: 0.7654 - val_loss: 0.4280 - val_accuracy: 0.8889
# Epoch 23/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5188 - accuracy: 0.7430 - val_loss: 0.4168 - val_accuracy: 0.8667
# Epoch 24/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4903 - accuracy: 0.7598 - val_loss: 0.3997 - val_accuracy: 0.8667
# Epoch 25/30
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4360 - accuracy: 0.8380 - val_loss: 0.3917 - val_accuracy: 0.8000
# Epoch 26/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5206 - accuracy: 0.7430 - val_loss: 0.4341 - val_accuracy: 0.8222
# Epoch 27/30
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4697 - accuracy: 0.8045 - val_loss: 0.3942 - val_accuracy: 0.8222
# Epoch 28/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4453 - accuracy: 0.8156 - val_loss: 0.3930 - val_accuracy: 0.8222
# Epoch 29/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4448 - accuracy: 0.8045 - val_loss: 0.3687 - val_accuracy: 0.8000
# Epoch 30/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4606 - accuracy: 0.7933 - val_loss: 0.4355 - val_accuracy: 0.8000
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4031 - accuracy: 0.8571
# 2/2 [==============================] - 0s 3ms/step - loss: 0.4699 - accuracy: 0.7895
# Evaluation on training set: loss 0.40305575728416443 accuracy 0.8571428656578064
# Evaluation on test set: loss 0.46991756558418274 accuracy 0.7894737124443054
# running time in  61.03040266036987 seconds
#
#
#
# training doc2vec for embedding size = 80
# the shape for training vector is (224, 80) the shape for test vector is (57, 80)
# training NN for embedding size = 80
# Epoch 1/30
# 6/6 [==============================] - 0s 28ms/step - loss: 0.8068 - accuracy: 0.4693 - val_loss: 0.6514 - val_accuracy: 0.6889
# Epoch 2/30
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6765 - accuracy: 0.5642 - val_loss: 0.6261 - val_accuracy: 0.6889
# Epoch 3/30
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6994 - accuracy: 0.5531 - val_loss: 0.6111 - val_accuracy: 0.7111
# Epoch 4/30
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6466 - accuracy: 0.5531 - val_loss: 0.5770 - val_accuracy: 0.7111
# Epoch 5/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6644 - accuracy: 0.5754 - val_loss: 0.5841 - val_accuracy: 0.7111
# Epoch 6/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6259 - accuracy: 0.6201 - val_loss: 0.5912 - val_accuracy: 0.7333
# Epoch 7/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6140 - accuracy: 0.6648 - val_loss: 0.5933 - val_accuracy: 0.7111
# Epoch 8/30
# 6/6 [==============================] - 0s 7ms/step - loss: 0.6211 - accuracy: 0.6592 - val_loss: 0.5802 - val_accuracy: 0.7111
# Epoch 9/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6057 - accuracy: 0.6425 - val_loss: 0.5707 - val_accuracy: 0.7556
# Epoch 10/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5751 - accuracy: 0.7207 - val_loss: 0.5463 - val_accuracy: 0.7556
# Epoch 11/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6044 - accuracy: 0.7095 - val_loss: 0.5406 - val_accuracy: 0.7111
# Epoch 12/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5522 - accuracy: 0.7486 - val_loss: 0.5065 - val_accuracy: 0.7778
# Epoch 13/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5723 - accuracy: 0.6983 - val_loss: 0.4921 - val_accuracy: 0.8000
# Epoch 14/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5359 - accuracy: 0.7598 - val_loss: 0.4772 - val_accuracy: 0.8000
# Epoch 15/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5320 - accuracy: 0.7151 - val_loss: 0.4865 - val_accuracy: 0.8222
# Epoch 16/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5293 - accuracy: 0.7374 - val_loss: 0.4808 - val_accuracy: 0.8222
# Epoch 17/30
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5149 - accuracy: 0.7709 - val_loss: 0.4640 - val_accuracy: 0.8000
# Epoch 18/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5262 - accuracy: 0.7430 - val_loss: 0.4308 - val_accuracy: 0.8000
# Epoch 19/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5267 - accuracy: 0.7598 - val_loss: 0.4680 - val_accuracy: 0.8000
# Epoch 20/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4997 - accuracy: 0.8101 - val_loss: 0.4364 - val_accuracy: 0.8667
# Epoch 21/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4725 - accuracy: 0.8156 - val_loss: 0.4149 - val_accuracy: 0.8667
# Epoch 22/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4608 - accuracy: 0.7933 - val_loss: 0.3753 - val_accuracy: 0.8667
# Epoch 23/30
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4590 - accuracy: 0.8101 - val_loss: 0.3587 - val_accuracy: 0.8667
# Epoch 24/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4939 - accuracy: 0.7765 - val_loss: 0.3880 - val_accuracy: 0.8667
# Epoch 25/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4652 - accuracy: 0.7989 - val_loss: 0.3892 - val_accuracy: 0.8889
# Epoch 26/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4524 - accuracy: 0.8324 - val_loss: 0.3833 - val_accuracy: 0.9111
# Epoch 27/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4641 - accuracy: 0.7877 - val_loss: 0.4107 - val_accuracy: 0.8222
# Epoch 28/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4718 - accuracy: 0.7765 - val_loss: 0.3566 - val_accuracy: 0.8889
# Epoch 29/30
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4341 - accuracy: 0.7877 - val_loss: 0.3593 - val_accuracy: 0.9111
# Epoch 30/30
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4243 - accuracy: 0.7989 - val_loss: 0.3381 - val_accuracy: 0.8889
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3418 - accuracy: 0.8973
# 2/2 [==============================] - 0s 3ms/step - loss: 0.4334 - accuracy: 0.8421
# Evaluation on training set: loss 0.3418000340461731 accuracy 0.8973214030265808
# Evaluation on test set: loss 0.4333670735359192 accuracy 0.8421052694320679
# running time in  52.75718283653259 seconds

# %%
fig, axes = plt.subplots(num_model, 2, figsize=(10, 15))
for i in range(num_model):
  hist = hist_list[i]
  ax1 = axes[i, 0]
  ax2 = axes[i, 1]

  ax1.plot(hist.history['loss'], label='training')
  ax1.plot(hist.history['val_loss'], label='validation')
  ax1.set_title('model loss, embedding = '+str(embed_size_list[i]))
  ax1.set_xlabel('epoch')
  ax1.set_ylabel('loss')
  ax1.legend(['train', 'test'], loc='upper left')
  
  ax2.plot(hist.history['accuracy'], label='training')
  ax2.plot(hist.history['val_accuracy'], label='validation')
  ax2.set_title('model accuracy, embedding = '+str(embed_size_list[i]))
  ax2.set_xlabel('epoch')
  ax2.set_ylabel('accuracy')
  ax2.legend(['train', 'validation'], loc='upper left')
fig.tight_layout()
