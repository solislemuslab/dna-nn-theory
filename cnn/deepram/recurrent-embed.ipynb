# %%
# !pip install -q biopython
# Out:
#      |████████████████████████████████| 2.3MB 6.3MB/s

# %%
from google.colab import drive
drive.mount('/content/drive')
DATA_DIR = '/content/drive/My Drive/data/ChIP-seq/'
LOG_DIR = '/content/drive/My Drive/dna-nn/embedding-recurrent/'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp -r '/content/drive/My Drive/dna_nn' .
# !ls dna_nn
# Out:
# download.py  load.py

# %%
from itertools import product
import gc

from Bio import SeqIO
import pandas as pd
import tensorflow as tf
from tensorflow import keras
from tensorflow.data import Dataset

from dna_nn.load import gen_from_fasta

# %%
vocab = [' '.join(p) for p in product('ACGT', repeat=1)]
vectorize_layer = keras.layers.experimental.preprocessing.TextVectorization(
    standardize=lambda x: tf.strings.regex_replace(x, '(.)', '\\1 '), ngrams=1
)
vectorize_layer.adapt(vocab)

# %%
def vectorize_text(x, y):
    x_index = vectorize_layer(x)
    return x_index, y

# %%
# generators
subset_size = 690 * 190

train_file = DATA_DIR + 'motif_discovery_train.fasta'
test_file = DATA_DIR + 'motif_discovery_test.fasta'
train_gen = gen_from_fasta(train_file, None)
test_gen = gen_from_fasta(test_file, None)

# datasets
bacth_size = 512
prefetch = tf.data.experimental.AUTOTUNE

output_shapes = ((), ())
output_types = (tf.string, tf.float32)

train_ds = Dataset.from_generator(train_gen, output_types, output_shapes)
val_ds = train_ds.skip(subset_size).take(690 * 10)
train_ds = train_ds.take(subset_size) \
            .shuffle(500) \
            .batch(bacth_size) \
            .map(vectorize_text) \
            .prefetch(prefetch)

val_ds = val_ds.map(vectorize_text) \
            .prefetch(prefetch)

test_ds = Dataset.from_generator(test_gen, output_types, output_shapes)
test_ds = test_ds.take(subset_size) \
            .batch(bacth_size) \
            .map(vectorize_text) \
            .prefetch(prefetch)

print('x shape:', train_ds.element_spec[0].shape)
print('y shape:', train_ds.element_spec[1].shape)
# Out:
# x shape: (None, None)
# y shape: (None,)

# %%
for d in train_ds.take(1):
    print(d[0].shape)
# Out:
# (512, 101)

# %%
# %%time
x_val, y_val = [], []
for d in val_ds:
    x_val.append(d[0])
    y_val.append(d[1])
x_val = tf.convert_to_tensor(x_val)
y_val = tf.convert_to_tensor(y_val)
validation_data = (x_val, y_val)
# Out:
# CPU times: user 28.4 s, sys: 2.71 s, total: 31.1 s
# Wall time: 34 s

# %%
keras.backend.clear_session()

model = keras.Sequential([
    keras.layers.Input(shape=(101)),
    keras.layers.Embedding(101, 256),
    keras.layers.Dropout(0.5),
    keras.layers.LSTM(64, return_sequences=True),
    keras.layers.LSTM(128),
    keras.layers.Dense(128),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1, activation='sigmoid')
])
model.summary()
auc = keras.metrics.AUC()
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy', auc])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 101, 256)          25856
# _________________________________________________________________
# dropout (Dropout)            (None, 101, 256)          0
# _________________________________________________________________
# lstm (LSTM)                  (None, 101, 64)           82176
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 128)               98816
# _________________________________________________________________
# dense (Dense)                (None, 128)               16512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 223,489
# Trainable params: 223,489
# Non-trainable params: 0
# _________________________________________________________________

# %%
version = 'v1-base'

callbacks = [
    keras.callbacks.CSVLogger(LOG_DIR + f'{version}.csv'),
    keras.callbacks.TensorBoard(log_dir=LOG_DIR + f'log/{version}/'),
    keras.callbacks.LambdaCallback(
        on_epoch_end=lambda epoch, logs: gc.collect(),
        on_train_end=lambda logs: model.save(LOG_DIR + f'{version}.h5')
    ),
]
history = model.fit(train_ds, epochs=30, validation_data=validation_data,
                    callbacks=callbacks)
# Out:
# Epoch 1/30
#       2/Unknown - 0s 129ms/step - loss: 0.6930 - accuracy: 0.5137 - auc: 0.5050WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0651s vs `on_train_batch_end` time: 0.1961s). Check your callbacks.
# 257/257 [==============================] - 28s 109ms/step - loss: 0.6932 - accuracy: 0.5068 - auc: 0.5088 - val_loss: 0.6924 - val_accuracy: 0.5123 - val_auc: 0.5180
# Epoch 2/30
# 257/257 [==============================] - 26s 101ms/step - loss: 0.6907 - accuracy: 0.5244 - auc: 0.5353 - val_loss: 0.6868 - val_accuracy: 0.5428 - val_auc: 0.5650
# Epoch 3/30
# 257/257 [==============================] - 26s 102ms/step - loss: 0.6790 - accuracy: 0.5703 - auc: 0.5969 - val_loss: 0.6704 - val_accuracy: 0.5864 - val_auc: 0.6232
# Epoch 4/30
# 257/257 [==============================] - 26s 101ms/step - loss: 0.6589 - accuracy: 0.6071 - auc: 0.6482 - val_loss: 0.6479 - val_accuracy: 0.6322 - val_auc: 0.6846
# Epoch 5/30
# 257/257 [==============================] - 27s 106ms/step - loss: 0.6329 - accuracy: 0.6429 - auc: 0.6950 - val_loss: 0.6257 - val_accuracy: 0.6588 - val_auc: 0.7191
# Epoch 6/30
# 257/257 [==============================] - 28s 108ms/step - loss: 0.6186 - accuracy: 0.6580 - auc: 0.7158 - val_loss: 0.6279 - val_accuracy: 0.6639 - val_auc: 0.7315
# Epoch 7/30
# 257/257 [==============================] - 28s 110ms/step - loss: 0.6054 - accuracy: 0.6709 - auc: 0.7335 - val_loss: 0.7172 - val_accuracy: 0.6322 - val_auc: 0.7410
# Epoch 8/30
# 257/257 [==============================] - 28s 107ms/step - loss: 0.6002 - accuracy: 0.6756 - auc: 0.7397 - val_loss: 0.5902 - val_accuracy: 0.6925 - val_auc: 0.7622
# Epoch 9/30
# 257/257 [==============================] - 28s 107ms/step - loss: 0.5870 - accuracy: 0.6863 - auc: 0.7550 - val_loss: 0.5749 - val_accuracy: 0.7052 - val_auc: 0.7735
# Epoch 10/30
# 257/257 [==============================] - 27s 107ms/step - loss: 0.5780 - accuracy: 0.6945 - auc: 0.7649 - val_loss: 0.5637 - val_accuracy: 0.7116 - val_auc: 0.7819
# Epoch 11/30
# 257/257 [==============================] - 27s 107ms/step - loss: 0.5688 - accuracy: 0.7019 - auc: 0.7742 - val_loss: 0.5649 - val_accuracy: 0.7152 - val_auc: 0.7890
# Epoch 12/30
# 257/257 [==============================] - 28s 108ms/step - loss: 0.5615 - accuracy: 0.7084 - auc: 0.7815 - val_loss: 0.5604 - val_accuracy: 0.7096 - val_auc: 0.7904
# Epoch 13/30
# 257/257 [==============================] - 27s 107ms/step - loss: 0.5536 - accuracy: 0.7135 - auc: 0.7888 - val_loss: 0.5412 - val_accuracy: 0.7304 - val_auc: 0.8023
# Epoch 14/30
# 257/257 [==============================] - 28s 107ms/step - loss: 0.5468 - accuracy: 0.7196 - auc: 0.7953 - val_loss: 0.5474 - val_accuracy: 0.7280 - val_auc: 0.8037
# Epoch 15/30
# 257/257 [==============================] - 27s 107ms/step - loss: 0.5392 - accuracy: 0.7258 - auc: 0.8021 - val_loss: 0.5303 - val_accuracy: 0.7378 - val_auc: 0.8126
# Epoch 16/30
# 257/257 [==============================] - 27s 107ms/step - loss: 0.5326 - accuracy: 0.7295 - auc: 0.8076 - val_loss: 0.5286 - val_accuracy: 0.7403 - val_auc: 0.8144
# Epoch 17/30
# 257/257 [==============================] - 28s 108ms/step - loss: 0.5253 - accuracy: 0.7343 - auc: 0.8138 - val_loss: 0.5291 - val_accuracy: 0.7341 - val_auc: 0.8173
# Epoch 18/30
# 257/257 [==============================] - 29s 111ms/step - loss: 0.5225 - accuracy: 0.7372 - auc: 0.8160 - val_loss: 0.5298 - val_accuracy: 0.7286 - val_auc: 0.8196
# Epoch 19/30
# 257/257 [==============================] - 28s 108ms/step - loss: 0.5157 - accuracy: 0.7409 - auc: 0.8215 - val_loss: 0.5183 - val_accuracy: 0.7455 - val_auc: 0.8222
# Epoch 20/30
# 257/257 [==============================] - 28s 110ms/step - loss: 0.5113 - accuracy: 0.7443 - auc: 0.8249 - val_loss: 0.5147 - val_accuracy: 0.7454 - val_auc: 0.8238
# Epoch 21/30
# 257/257 [==============================] - 28s 109ms/step - loss: 0.5071 - accuracy: 0.7476 - auc: 0.8283 - val_loss: 0.5180 - val_accuracy: 0.7441 - val_auc: 0.8262
# Epoch 22/30
# 257/257 [==============================] - 27s 107ms/step - loss: 0.5012 - accuracy: 0.7506 - auc: 0.8325 - val_loss: 0.5319 - val_accuracy: 0.7352 - val_auc: 0.8267
# Epoch 23/30
# 257/257 [==============================] - 28s 109ms/step - loss: 0.4988 - accuracy: 0.7533 - auc: 0.8346 - val_loss: 0.5224 - val_accuracy: 0.7329 - val_auc: 0.8278
# Epoch 24/30
# 257/257 [==============================] - 28s 107ms/step - loss: 0.4944 - accuracy: 0.7551 - auc: 0.8376 - val_loss: 0.5124 - val_accuracy: 0.7486 - val_auc: 0.8298
# Epoch 25/30
# 257/257 [==============================] - 27s 107ms/step - loss: 0.4905 - accuracy: 0.7571 - auc: 0.8405 - val_loss: 0.5088 - val_accuracy: 0.7487 - val_auc: 0.8318
# Epoch 26/30
# 257/257 [==============================] - 28s 107ms/step - loss: 0.4841 - accuracy: 0.7610 - auc: 0.8451 - val_loss: 0.5130 - val_accuracy: 0.7481 - val_auc: 0.8311
# Epoch 27/30
# 257/257 [==============================] - 27s 107ms/step - loss: 0.4791 - accuracy: 0.7636 - auc: 0.8484 - val_loss: 0.5133 - val_accuracy: 0.7516 - val_auc: 0.8323
# Epoch 28/30
# 257/257 [==============================] - 27s 107ms/step - loss: 0.4763 - accuracy: 0.7659 - auc: 0.8505 - val_loss: 0.5065 - val_accuracy: 0.7523 - val_auc: 0.8314
# Epoch 29/30
# 257/257 [==============================] - 29s 111ms/step - loss: 0.4702 - accuracy: 0.7699 - auc: 0.8547 - val_loss: 0.5111 - val_accuracy: 0.7457 - val_auc: 0.8299
# Epoch 30/30
# 257/257 [==============================] - 27s 107ms/step - loss: 0.4656 - accuracy: 0.7724 - auc: 0.8580 - val_loss: 0.5172 - val_accuracy: 0.7442 - val_auc: 0.8273

# %%
ax = pd.DataFrame(history.history).plot()
ax.legend(bbox_to_anchor=(1, 1), loc='upper left')
ax.grid()

# %%
model.evaluate(test_ds)
# Out:
# 257/257 [==============================] - 23s 91ms/step - loss: 0.5212 - accuracy: 0.7443 - auc: 0.8235
# [0.5211902260780334, 0.744340181350708, 0.8234620690345764]
