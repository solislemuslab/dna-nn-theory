# %%
# !pip install -q biopython
# Out:
#      |████████████████████████████████| 2.3MB 8.2MB/s

# %%
from google.colab import drive
drive.mount('/content/drive')
DATA_DIR = '/content/drive/My Drive/data/ChIP-seq/'
LOG_DIR = '/content/drive/My Drive/dna-nn/embedding-conv1d-recurrent/'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp -r '/content/drive/My Drive/dna_nn' .
# !ls dna_nn
# Out:
# download.py  load.py

# %%
from itertools import product
import gc

from Bio import SeqIO
import pandas as pd
import tensorflow as tf
from tensorflow import keras
from tensorflow.data import Dataset

from dna_nn.load import gen_from_fasta

# %%
vocab = [' '.join(p) for p in product('ACGT', repeat=1)]
vectorize_layer = keras.layers.experimental.preprocessing.TextVectorization(
    standardize=lambda x: tf.strings.regex_replace(x, '(.)', '\\1 '), ngrams=1
)
vectorize_layer.adapt(vocab)

# %%
def vectorize_text(x, y):
    x_index = vectorize_layer(x)
    return x_index, y

# %%
# generators
subset_size = 690 * 190

train_file = DATA_DIR + 'motif_discovery_train.fasta'
test_file = DATA_DIR + 'motif_discovery_test.fasta'
train_gen = gen_from_fasta(train_file, None)
test_gen = gen_from_fasta(test_file, None)

# datasets
bacth_size = 512
prefetch = tf.data.experimental.AUTOTUNE

output_shapes = ((), ())
output_types = (tf.string, tf.float32)

train_ds = Dataset.from_generator(train_gen, output_types, output_shapes)
val_ds = train_ds.skip(subset_size).take(690 * 10)
train_ds = train_ds.take(subset_size) \
            .shuffle(500) \
            .batch(bacth_size) \
            .map(vectorize_text) \
            .prefetch(prefetch)

val_ds = val_ds.map(vectorize_text) \
            .prefetch(prefetch)

test_ds = Dataset.from_generator(test_gen, output_types, output_shapes)
test_ds = test_ds.take(subset_size) \
            .batch(bacth_size) \
            .map(vectorize_text) \
            .prefetch(prefetch)

print('x shape:', train_ds.element_spec[0].shape)
print('y shape:', train_ds.element_spec[1].shape)
# Out:
# x shape: (None, None)
# y shape: (None,)

# %%
for d in train_ds.take(1):
    print(d[0].shape)
# Out:
# (512, 101)

# %%
# %%time
x_val, y_val = [], []
for d in val_ds:
    x_val.append(d[0])
    y_val.append(d[1])
x_val = tf.convert_to_tensor(x_val)
y_val = tf.convert_to_tensor(y_val)
validation_data = (x_val, y_val)
# Out:
# CPU times: user 26.9 s, sys: 2.52 s, total: 29.4 s
# Wall time: 32.1 s

# %%
keras.backend.clear_session()

model = keras.Sequential([
    keras.layers.Input(shape=(101)),
    keras.layers.Embedding(101, 256),
    keras.layers.Dropout(0.5),
    keras.layers.Conv1D(64, 3, activation='relu'),
    keras.layers.MaxPooling1D(),
    keras.layers.Conv1D(128, 3, activation='relu'),
    keras.layers.MaxPooling1D(),
    keras.layers.LSTM(64, return_sequences=True),
    keras.layers.LSTM(128),
    keras.layers.Dense(128),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1, activation='sigmoid')
])
model.summary()
auc = keras.metrics.AUC()
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy', auc])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 101, 256)          25856
# _________________________________________________________________
# dropout (Dropout)            (None, 101, 256)          0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 99, 64)            49216
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 49, 64)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 47, 128)           24704
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 23, 128)           0
# _________________________________________________________________
# lstm (LSTM)                  (None, 23, 64)            49408
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 128)               98816
# _________________________________________________________________
# dense (Dense)                (None, 128)               16512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 264,641
# Trainable params: 264,641
# Non-trainable params: 0
# _________________________________________________________________

# %%
version = 'v3-base'

callbacks = [
    keras.callbacks.CSVLogger(LOG_DIR + f'{version}.csv'),
    keras.callbacks.TensorBoard(log_dir=LOG_DIR + f'log/{version}/'),
    keras.callbacks.LambdaCallback(
        on_epoch_end=lambda epoch, logs: gc.collect(),
        on_train_end=lambda logs: model.save(LOG_DIR + f'{version}.h5')
    ),
]
history = model.fit(train_ds, epochs=30, validation_data=validation_data,
                    callbacks=callbacks)
# Out:
# Epoch 1/30
#       2/Unknown - 0s 164ms/step - loss: 0.6945 - accuracy: 0.4844 - auc: 0.4786WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0476s vs `on_train_batch_end` time: 0.2825s). Check your callbacks.
# 257/257 [==============================] - 28s 111ms/step - loss: 0.6912 - accuracy: 0.5140 - auc: 0.5243 - val_loss: 0.6741 - val_accuracy: 0.5835 - val_auc: 0.6173
# Epoch 2/30
# 257/257 [==============================] - 26s 102ms/step - loss: 0.6516 - accuracy: 0.6164 - auc: 0.6622 - val_loss: 0.6005 - val_accuracy: 0.6806 - val_auc: 0.7409
# Epoch 3/30
# 257/257 [==============================] - 26s 102ms/step - loss: 0.6003 - accuracy: 0.6757 - auc: 0.7391 - val_loss: 0.5672 - val_accuracy: 0.7046 - val_auc: 0.7769
# Epoch 4/30
# 257/257 [==============================] - 26s 101ms/step - loss: 0.5716 - accuracy: 0.7003 - auc: 0.7710 - val_loss: 0.5452 - val_accuracy: 0.7203 - val_auc: 0.8015
# Epoch 5/30
# 257/257 [==============================] - 26s 102ms/step - loss: 0.5456 - accuracy: 0.7201 - auc: 0.7959 - val_loss: 0.5493 - val_accuracy: 0.7186 - val_auc: 0.8170
# Epoch 6/30
# 257/257 [==============================] - 26s 102ms/step - loss: 0.5307 - accuracy: 0.7313 - auc: 0.8090 - val_loss: 0.5414 - val_accuracy: 0.7210 - val_auc: 0.8237
# Epoch 7/30
# 257/257 [==============================] - 26s 101ms/step - loss: 0.5177 - accuracy: 0.7396 - auc: 0.8195 - val_loss: 0.5093 - val_accuracy: 0.7480 - val_auc: 0.8322
# Epoch 8/30
# 257/257 [==============================] - 26s 102ms/step - loss: 0.5053 - accuracy: 0.7488 - auc: 0.8295 - val_loss: 0.4984 - val_accuracy: 0.7529 - val_auc: 0.8359
# Epoch 9/30
# 257/257 [==============================] - 26s 102ms/step - loss: 0.4968 - accuracy: 0.7535 - auc: 0.8359 - val_loss: 0.4962 - val_accuracy: 0.7572 - val_auc: 0.8386
# Epoch 10/30
# 257/257 [==============================] - 26s 101ms/step - loss: 0.4851 - accuracy: 0.7612 - auc: 0.8445 - val_loss: 0.4887 - val_accuracy: 0.7601 - val_auc: 0.8424
# Epoch 11/30
# 257/257 [==============================] - 26s 101ms/step - loss: 0.4782 - accuracy: 0.7665 - auc: 0.8494 - val_loss: 0.5067 - val_accuracy: 0.7503 - val_auc: 0.8411
# Epoch 12/30
# 257/257 [==============================] - 26s 103ms/step - loss: 0.4721 - accuracy: 0.7697 - auc: 0.8536 - val_loss: 0.5030 - val_accuracy: 0.7557 - val_auc: 0.8382
# Epoch 13/30
# 257/257 [==============================] - 27s 106ms/step - loss: 0.4657 - accuracy: 0.7739 - auc: 0.8579 - val_loss: 0.5030 - val_accuracy: 0.7516 - val_auc: 0.8451
# Epoch 14/30
# 257/257 [==============================] - 26s 101ms/step - loss: 0.4584 - accuracy: 0.7793 - auc: 0.8630 - val_loss: 0.4863 - val_accuracy: 0.7626 - val_auc: 0.8460
# Epoch 15/30
# 257/257 [==============================] - 26s 102ms/step - loss: 0.4527 - accuracy: 0.7826 - auc: 0.8667 - val_loss: 0.4854 - val_accuracy: 0.7626 - val_auc: 0.8471
# Epoch 16/30
# 257/257 [==============================] - 26s 101ms/step - loss: 0.4447 - accuracy: 0.7878 - auc: 0.8717 - val_loss: 0.4993 - val_accuracy: 0.7574 - val_auc: 0.8461
# Epoch 17/30
# 257/257 [==============================] - 26s 101ms/step - loss: 0.4378 - accuracy: 0.7923 - auc: 0.8759 - val_loss: 0.4906 - val_accuracy: 0.7630 - val_auc: 0.8459
# Epoch 18/30
# 257/257 [==============================] - 26s 101ms/step - loss: 0.4301 - accuracy: 0.7964 - auc: 0.8807 - val_loss: 0.4951 - val_accuracy: 0.7587 - val_auc: 0.8437
# Epoch 19/30
# 257/257 [==============================] - 26s 101ms/step - loss: 0.4229 - accuracy: 0.8009 - auc: 0.8851 - val_loss: 0.5005 - val_accuracy: 0.7587 - val_auc: 0.8418
# Epoch 20/30
# 257/257 [==============================] - 26s 101ms/step - loss: 0.4148 - accuracy: 0.8050 - auc: 0.8899 - val_loss: 0.5095 - val_accuracy: 0.7572 - val_auc: 0.8394
# Epoch 21/30
# 257/257 [==============================] - 26s 101ms/step - loss: 0.4062 - accuracy: 0.8106 - auc: 0.8946 - val_loss: 0.5383 - val_accuracy: 0.7441 - val_auc: 0.8410
# Epoch 22/30
# 257/257 [==============================] - 26s 102ms/step - loss: 0.3972 - accuracy: 0.8149 - auc: 0.8995 - val_loss: 0.5267 - val_accuracy: 0.7500 - val_auc: 0.8357
# Epoch 23/30
# 257/257 [==============================] - 26s 101ms/step - loss: 0.3852 - accuracy: 0.8220 - auc: 0.9058 - val_loss: 0.5266 - val_accuracy: 0.7517 - val_auc: 0.8357
# Epoch 24/30
# 257/257 [==============================] - 27s 105ms/step - loss: 0.3768 - accuracy: 0.8263 - auc: 0.9101 - val_loss: 0.5461 - val_accuracy: 0.7423 - val_auc: 0.8275
# Epoch 25/30
# 257/257 [==============================] - 27s 104ms/step - loss: 0.3626 - accuracy: 0.8341 - auc: 0.9172 - val_loss: 0.5511 - val_accuracy: 0.7433 - val_auc: 0.8248
# Epoch 26/30
# 257/257 [==============================] - 26s 101ms/step - loss: 0.3488 - accuracy: 0.8407 - auc: 0.9236 - val_loss: 0.5978 - val_accuracy: 0.7306 - val_auc: 0.8180
# Epoch 27/30
# 257/257 [==============================] - 26s 101ms/step - loss: 0.3371 - accuracy: 0.8465 - auc: 0.9289 - val_loss: 0.5955 - val_accuracy: 0.7445 - val_auc: 0.8228
# Epoch 28/30
# 257/257 [==============================] - 26s 101ms/step - loss: 0.3277 - accuracy: 0.8523 - auc: 0.9330 - val_loss: 0.6464 - val_accuracy: 0.7404 - val_auc: 0.8193
# Epoch 29/30
# 257/257 [==============================] - 26s 101ms/step - loss: 0.3191 - accuracy: 0.8563 - auc: 0.9367 - val_loss: 0.6533 - val_accuracy: 0.7354 - val_auc: 0.8194
# Epoch 30/30
# 257/257 [==============================] - 26s 101ms/step - loss: 0.3120 - accuracy: 0.8608 - auc: 0.9397 - val_loss: 0.6458 - val_accuracy: 0.7346 - val_auc: 0.8111

# %%
ax = pd.DataFrame(history.history).plot()
ax.legend(bbox_to_anchor=(1, 1), loc='upper left')
ax.grid()

# %%
model.evaluate(test_ds)
# Out:
# 257/257 [==============================] - 24s 94ms/step - loss: 0.6558 - accuracy: 0.7295 - auc: 0.8048
# [0.655846118927002, 0.7295423150062561, 0.8047727346420288]
